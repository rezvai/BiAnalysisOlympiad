# %% [markdown]
# # Предобработка количественных данных

# %% [markdown]
# ________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 1. Загрузка данных
# - #### 1.1 Я произвел загрузку данных из веб-приложения РосНавык все данные находятся в папке -> data -> dirtydata -> csvdirtydata.csv.
# ![Снимок экрана 2024-04-03 103319.png](<attachment:Снимок экрана 2024-04-03 103319.png>)
# ![Снимок экрана 2024-04-03 102046.png](<attachment:Снимок экрана 2024-04-03 102046.png>)
# - #### 1.2 Я выгрузил все перечисленные поля для выгрузки в задании.
# ![Снимок экрана 2024-04-03 110658.png](<attachment:Снимок экрана 2024-04-03 110658.png>)
# - #### 1.3 Все выгруженные вакансии были выгруженны за последний 3 месяца.
# ![Снимок экрана 2024-04-03 110632.png](<attachment:Снимок экрана 2024-04-03 110632.png>)

# %% [markdown]
# ________________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 2. Предварительная обработка данных
# - #### 2.1 Я провел предобработку данных: привел все данные к нижнему регистру, избавился от ненужных значений в полях.
# - #### 2.2 Я задал верную структуру базе данных: добавил поле ID и задал ему значение первичного ключа(Primary Key).
# ![Снимок экрана 2024-04-03 110353.png](<attachment:Снимок экрана 2024-04-03 110353.png>)
# - #### 2.3 Определил кретические пропущенные значения и обосновал их в файле -> Report.html, а после провел с ними работу, выбрав удаление строк с пропусками в этом поле.
# ![Снимок экрана 2024-04-03 103241.png](<attachment:Снимок экрана 2024-04-03 103241.png>)![Снимок экрана 2024-04-03 110258.png](<attachment:Снимок экрана 2024-04-03 110258.png>)
# - #### 2.4 Преобразовал типы данных в Базе данных: publication_date::date, salary::int, id::serial, остальные поля::text.
# ![Снимок экрана 2024-04-03 110422.png](<attachment:Снимок экрана 2024-04-03 110422.png>)
# - #### 2.5 Сделал краткое описание каждого атрибута базы данных в файле -> Report.html.
# ![Снимок экрана 2024-04-03 103241.png](<attachment:Снимок экрана 2024-04-03 103241.png>)
# ![Снимок экрана 2024-04-03 110220.png](<attachment:Снимок экрана 2024-04-03 110220.png>)

# %% [markdown]
# ____________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 3. Реализация запросов
# - #### 3.1 При обработке данных я использовал запросы к базе данных, сохранив все запросы в файле -> ModuleA.sql.
# ![Снимок экрана 2024-04-03 103200.png](<attachment:Снимок экрана 2024-04-03 103200.png>)
# - #### 3.2 Также я реализовал некторые анализы данных с помощью sql, сохранив все запросы в файле -> ModuleA.sql.
# ![Снимок экрана 2024-04-03 103200.png](<attachment:Снимок экрана 2024-04-03 103200.png>)
# ![Снимок экрана 2024-04-03 110515.png](<attachment:Снимок экрана 2024-04-03 110515.png>)
# - #### 3.3 Я постарался покрыть все запросы к базе данных информативными комментариями.

# %% [markdown]
# ________________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 4. Подготовка отчетов
# - #### 4.1 Я подготовил отчет о проделанной работе в файле -> Report_M1.ipynb.
# ![Снимок экрана 2024-04-03 103223.png](<attachment:Снимок экрана 2024-04-03 103223.png>)
# - #### 4.2 Отчет охыватывает все этапы проделанной работы.

# %% [markdown]
# ____________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 5. Полученная базы данных
# - #### 5.1 Полученную базу данных я скохранил в папке -> data -> cleardata -> cleardata.csv(чтобы увидеть ее содержание, нужно изменить кодировку на utf-8).
# ![Снимок экрана 2024-04-03 103431.png](<attachment:Снимок экрана 2024-04-03 103431.png>)

# %% [markdown]
# ____________________________________________________________________________________________________________________________________________________________________________________________________________
