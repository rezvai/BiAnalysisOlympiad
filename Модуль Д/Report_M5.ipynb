# %% [markdown]
# # Презентация решения

# %% [markdown]
# ___________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 1. Разработка документации системы
# - #### 1.1 Была разработанна документация, охватывающую всю систему в файле -> Report.ipynb.
# ![image.png](attachment:image.png)
# - #### 1.2 В документации присуствуют подсказки для работы с системой в файле -> Report.ipynb.
# ![image.png](attachment:image.png)

# %% [markdown]
# ___________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 2. Презентация результатов работы
# - #### 2.1 Была создана презентация, охватывающая все этапы работы в файле -> Project.pptx.
# ![image.png](attachment:image.png)
# - #### 2.2 Презентация содержит в себе все необходимые по заданию разделы.
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ___________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 3. Устный доклад
# - #### 3.1 К созданой презентации был подготовлен емкий устный доклад, охватывающий все результаты работы.

# %% [markdown]
# ___________________________________________________________________________________________________________________________________________________________________________________________________
