# %% [markdown]
# # Сетевой анализ данных

# %% [markdown]
# ________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 1. Построение графа связей
# - #### 1.1 Перед постройкой графа связей я подготовил данные и сохранил их в формате Excel.
# #### Были загружены данные из текстового файла с прошлуга модуля в файле -> preprocess.ipynb -> пункт 1 -> подпункт 1.1
# ![image-11.png](attachment:image-11.png)
# #### Были посчитано количество встречаемости пар вместе в файле -> preprocess.ipynb -> пункт 1 -> подпункт 1.2
# ![image-12.png](attachment:image-12.png)
# #### Программно была пострена таблицы в формате .xlsx
# ![image-10.png](attachment:image-10.png) -> ![image-13.png](attachment:image-13.png)
# - #### 1.2 Интерактивный граф связей был построен в файле -> RabovModuleГ.pbix.
# ![image-2.png](attachment:image-2.png) -> ![image.png](attachment:image.png)
# - #### 1.3 Интерактивный граф связей был сохранен в визуальном формате в файле -> RabovModuleГ.pbix.
# ![image-2.png](attachment:image-2.png) -> ![image.png](attachment:image.png)
# - #### 1.4 Граф связей позволяет понять как часто один навык встречается с другими навыками в паре.
# #### Неообходимо нажать на элемент графа на дашборде, он выделится рамкой, а после появляется фильтры для данного элемента. Необходимо выбрать фильтр для атрибута: "Количество встречаемости навыков вместе"
# ![image-3.png](attachment:image-3.png) -> ![image-4.png](attachment:image-4.png) -> ![image-5.png](attachment:image-5.png)
# #### Приступим к выбору количества встречаемости навыков вместе, теперь необходимо выбрать значение, которые мы хотим посмотреть, например элементы, встречающиеся 8 раз, для этого нужно нажать на чекбокс с цифрой "8". Справа от цифры 8 пишется количество элементов, которые присутсвует на данном графе, то есть 296 элементов, которые встречаются вместе 8 раз.
# ![image-6.png](attachment:image-6.png)
# #### Чтобы понять какие элементы встречаются вместе, необходимо навести на вершину графу, одсветится вершина, а также линии, которые идут к другим вершинам, связанным с этой вершиной
# ![image-7.png](attachment:image-7.png)
# - #### 1.5 Для построенного графа были описаны и посчитаны основые метрики в файле -> Report_M4.html.
# ![image-8.png](attachment:image-8.png) -> ![image-9.png](attachment:image-9.png)

# %% [markdown]
# ________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# # 2. Подготовка рекомендации образовательным орагизациям
# - #### 2.1 Я составил рекомендации образовательным организациям на основе проведенного анализа, приложил в рекомендации данные, использовавшиеся в анализе, а также обосновал свои решения
# ![image.png](attachment:image.png) -> ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ________________________________________________________________________________________________________________________________________________________________
