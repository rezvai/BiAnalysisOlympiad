# %% [markdown]
# # Анализ количественных данных

# %% [markdown]
# ____________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 1. Построение интерактивного дашборда
# - #### 1.1 Построен интерактивный(при нажатие на элементы дашборда другие значения зависимо меняются) дашборд в файле -> RabovModuleБ.pbix.
# ![image-4.png](attachment:image-4.png)
# - #### 1.2 На дашборде присутсвуют все необходимые элементы по заданию в файле -> RabovModuleБ.pbix.
# ![image.png](attachment:image.png)
# ![image-8.png](attachment:image-8.png)
# - #### 1.3 Данные на дашборде кластеризованны - к вакансии может относиться несколько работодателей или наоборот, к работодателю несколько вакансий.
# ![image-2.png](attachment:image-2.png) ![image-9.png](attachment:image-9.png)
# - #### 1.4 Количественные переменные распределенны на категории или интервалы в файле -> RabovModule.pbix переменные: salary, график динамики вакансий по месяцам - представленны в виде интервалы, для более удобного визуального анализа.
# ![image-3.png](attachment:image-3.png)
# - #### 1.5 Коррелирующие переменные отфильтрованны самой программой Power BI и не мешают проведению визуального анализа.
# - #### 1.6 Выполнена интеграция в дашборд базы данных Postgres, чтобы произвести обновление данных, необходимо:
# #### Зайти в дашборд  в файле -> RabovModuleБ.pbix -> перейти во вкладку настройки моделей данных -> нажать на 3 точки у модели данных -> нажать пункт "Обновить данные"
# #### Визуальная инсрукция:
# #### ![image-4.png](attachment:image-4.png) -> ![image-6.png](attachment:image-6.png) -> ![image-5.png](attachment:image-5.png) -> ![image-7.png](attachment:image-7.png)

# %% [markdown]
# ____________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 2. Составление аналитической записки
# - #### 2.1 К построенному дашборду составленна подробная анлитическая записка в файле -> Analysisnote.docx.
# ![image.png](attachment:image.png)
# - #### 2.2 В построенной аналитической записке присуствуют графики и диаграммы, использовавшиеся при анализе в файле -> Analysisnote.pbix -> Данные и графики, использовавшиеся в анализе.
# ![image.png](attachment:image.png) -> ![image-3.png](attachment:image-3.png)

# %% [markdown]
# __________________________________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 3. Исследовательский анализ
# - #### 3.1 Я выявил и описал характеристики, проявляющие наиболее устойчивые закономерности в файле -> Report.html.
# ![image.png](attachment:image.png) -> ![image-5.png](attachment:image-5.png)
# - #### 3.2 Корреляционный анализ выполнен программно в файле -> cor.ipynb.
# ![image-2.png](attachment:image-2.png) -> ![image-3.png](attachment:image-3.png)
# - #### 3.3 Я провел поиск зависимостей между заработной платой и опытом работы, а также описал их в файле -> Report.html.
# ![image.png](attachment:image.png) -> ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ______________________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 4. Проектирование защиты информационно аналитической системы
# - #### 4.1 Я создал защиту данных в дашборде, реализовав в нем роли с разным доступом к данным, инструкция по просмотру ролей:
# #### Зайти в дашборд  в файле -> RabovModuleБ.pbix -> перейти во вкладку моделирование -> нажать на пункт "Посмотреть как" -> выбрать необходимую роль и подтвердить.
# #### Визуальная инсрукция:
# #### ![image.png](attachment:image.png) -> ![image-2.png](attachment:image-2.png) -> ![image-3.png](attachment:image-3.png)
# #### Пояснение: созданные роли позволяют смотреть данные относительно регионов. Например, пользователь user_moscow может проссматривать данные только про Московский регион. Пользователь admin имеет полный доступ к данным.

# %% [markdown]
# ______________________________________________________________________________________________________________________________________________________________________________________________________________________________
