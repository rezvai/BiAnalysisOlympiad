# %% [markdown]
# # Обработка и анализ текстовых данных

# %% [markdown]
# ______________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# # 1. Определение ключевых навыков
# - #### 1.1 Я определил ключевые навыки и описал их в файле -> Report_M3.html -> Выявление ключевых навыков из описаний вакансий.
# ![image.png](attachment:image.png) -> ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ______________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# # 2. Анализ текста
# - #### 2.1 Перед анализом текста я загрузил данные из Базы Данных в файле -> model.ipynb -> 1 пункт.
# ![image.png](attachment:image.png)
# - #### 2.2 После загрузки данных я предобработал данные для дальнейшего применения NLP алгоритмов в файле -> model.ipynb -> 2 пункт.
# ![image-2.png](attachment:image-2.png)
# - #### 2.3 После предобработки данных и проведения с ними манипуляций, я приступил к реализации NLP алгоритмов в файле -> model.ipynb -> 3 пункт.
# ![image-3.png](attachment:image-3.png)
# - #### 2.4 Для начала я провел выявление связей между словами и семантический анализ предложений путем векторизации слов моделью RuBert, а после сравнил вектора слов, использую алгоритм K-Nearest Neighbors(KNN) в файле -> model.ipynb -> 3 пункт -> 3.1 подпункт.
# ![image-4.png](attachment:image-4.png)
# #### Пояснение - где я провожу вывление связей между словами и семантический анализ предложений:
# ![image-5.png](attachment:image-5.png)
# - #### 2.5 Перед обучением KNN я описал функциональные роли слов в файле -> model.ipynb -> 3 пункт -> 3.1 подпункт.
# ![image-4.png](attachment:image-4.png)
# #### Пояснение - где я привожу описание функиональных ролей слов:
# ![image-5.png](attachment:image-5.png)
# - #### 2.6 После проведения всех анализов связей между словами и описание функциональных ролей слов я приступаю к обучению ML(Machine Learning) алгоритма KNN в файле -> model.ipynb -> 3 пункт -> 3.1 подпункт.
# ![image-6.png](attachment:image-6.png)
# - #### 2.7 После успешного обучения своей модели я использую ее для классификации всех слов из описаний вакансий в файле -> model.ipynb -> 3 пункт -> 3.2 подпункт.
# #### Весь код:
# ![image-7.png](attachment:image-7.png)
# #### Отдел кода, где я использую модель:
# ![image-8.png](attachment:image-8.png)
# #### После присвоения классов словам я отсеиваю слова с классом: "Не навык":
# ![image-9.png](attachment:image-9.png)
# #### Результаты работы модели:
# ![image-10.png](attachment:image-10.png)
# - #### 2.8 После успешной классификации всех слов, я продолжаю работать со словами, у которых класс "Навык" и реализую для них кластеризатор, который разбивает слова на схожие группы в файле -> model.ipynb -> 3 пункт -> 3.3 подпункт.
# #### Весь код:
# ![image-11.png](attachment:image-11.png)
# #### Сначала я токенезирую слова
# ![image-12.png](attachment:image-12.png)
# #### Дальше использую модель RuBert, чтобы векторизовать слова:
# ![image-13.png](attachment:image-13.png)
# #### В самом конце кода я разбиваю все навыки на 3 группы, относя каждое слово к своей группе относителньо определенного лейбла у KMeans:
# ![image-14.png](attachment:image-14.png)
# #### Результаты работы модели:
# ![image-15.png](attachment:image-15.png)
# - #### 2.8 После применения всех алгоритмов NLP к данным я начинаю их анализировать в файле -> model.ipynb -> 4 пункт.
# ![image-16.png](attachment:image-16.png)
# #### Определение наиболее востребованных и наименее востребованных навыковдля выбранной группы вакансий:
# ![image-17.png](attachment:image-17.png)
# #### Определение наиболее высокооплачеваемые навыки:
# ![image-18.png](attachment:image-18.png)
# #### Определение региональную специфику востребованных навыков
# ![image-19.png](attachment:image-19.png)
# - #### 2.9 В заключающем этапе я программно(используя Python) сохраняю все данные в таблице Excel формата .xlsx в файле -> model.ipynb -> 5 пункт.
# ![image-20.png](attachment:image-20.png)
# #### Таблица имеет следующие поля: навык(имя навыка), количество(встречаемость навыка в кластере), кластер:
# ![image-21.png](attachment:image-21.png)

# %% [markdown]
# _____________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 3. Визуальный анализ текстовых данных
# - #### 3.1 При визуальном анализе текстовых данных я построил интерактивный дашборд в файле -> RabovModuleB.pbix.
# ![image-2.png](attachment:image-2.png) -> ![image.png](attachment:image.png)
# - #### 3.2 Дашборд полностью интерактивный, при нажатие на любой элемент, другие элементы также меняются в файле -> RabovModuleB.pbix.
# ![image.png](attachment:image.png) -> ![image-3.png](attachment:image-3.png)
# - #### 3.3 В дашборде реализованны методы защиты данных, создано три пользователя под каждый кластер - пользователь "user_cluster1" может проссматривать информация по кластеру один, остальные пользователи также проссматривают информацию только для свеого заданного кластера в файле -> RabovModuleB.pbix -> вкладка моделирование -> посмотреть как -> выбрать пользователя и подтвердить.
# #### Визуальная инструкция:
# ![image-2.png](attachment:image-2.png) -> ![image-4.png](attachment:image-4.png) -> ![image-5.png](attachment:image-5.png) -> ![image-6.png](attachment:image-6.png)
# - #### 3.4 Для дашборда описаны функциональные требования в файле -> Report_M3.html -> Пункт "описание функциональных требований дашборда"
# ![image-7.png](attachment:image-7.png) -> ![image-8.png](attachment:image-8.png)

# %% [markdown]
# ________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# # 4. Подготовка аналитической записки
# - #### 4.1 Я подготовил аналитическую записку в формате .docx, охватывающую все проведенные анализы в файле -> Annotationsnote.docx.
# ![image.png](attachment:image.png) -> ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ____________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________
